# %%
import matplotlib.pyplot as plt
import numpy as np

# データの定義
n_values = [4, 6, 7, 8]  # n の値
augmentation_counts = [2**n for n in n_values]  # 拡張数を 2^n の形で計算

# メソッドごとの Fβ スコアを辞書で管理
f_beta_scores = {
    "Method 1": [0.08, 0.61, 0.78, 0.50],
    "Method 2": [0.44, 0.48, 0.45, 0.45],
    "Method 3": [0.11, 0.37, 0.41, 0.60]
    # 新しいメソッドをここに追加可能
    # "Method 3": [0.40, 0.43, 0.44, 0.48],
}

# プロットの作成
plt.figure(figsize=(8, 6))

# 各メソッドをプロット
for method, scores in f_beta_scores.items():
    plt.plot(n_values, scores, marker='o', label=method)

# 軸ラベルとタイトルの設定
plt.title('f0.5 Score vs Number of Augmentations (2^n)', fontsize=16)
plt.xlabel('n (Number of Augmentations = $2^n$)', fontsize=14)
plt.ylabel('f0.5 Score', fontsize=14)

# X軸の目盛りをカスタマイズ（n の値）
plt.xticks(n_values, [f'$2^{n}$' for n in n_values])

# グリッドの表示
plt.grid(True, linestyle='--', alpha=0.6)

# 凡例の追加
plt.legend(fontsize=12)

# プロットの表示
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データの定義
n_values = [4, 6, 7, 8]  # n の値
augmentation_counts = [2**n for n in n_values]  # 拡張数を 2^n の形で計算

# メソッドごとの Fβ スコアを辞書で管理
f_beta_scores = {
    "Method 1": [0.40, 0.47, 0.49, 0.46],
    "Method 2": [0.44, 0.48, 0.45, 0.45],
    "Method 3": [0.34, 0.43, 0.48, 0.52]
}

# プロットの作成
plt.figure(figsize=(8, 6))

# 各メソッドをプロット
for method, scores in f_beta_scores.items():
    if method == "Method 3":
        plt.plot(n_values, scores, marker='o', label=method, color='orange')  # Method 3 をオレンジに
    else:
        plt.plot(n_values, scores, marker='o', label=method)

# 軸ラベルとタイトルの設定
plt.title('Fβ Score vs Number of Augmentations (2^n)', fontsize=16)
plt.xlabel('n (Number of Augmentations = $2^n$)', fontsize=14)
plt.ylabel('Fβ Score', fontsize=14)

# X軸の目盛りをカスタマイズ（n の値）
plt.xticks(n_values, [f'$2^{n}$' for n in n_values])

# グリッドの表示
plt.grid(True, linestyle='--', alpha=0.6)

# 凡例の追加
plt.legend(fontsize=12)

# プロットの表示
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データの定義
n_values = [4, 6, 7, 8]  # n の値
augmentation_counts = [2**n for n in n_values]  # 拡張数を 2^n の形で計算

# メソッドごとの Fβ スコアを辞書で管理
f_beta_scores = {
    "Method 1": [0.08, 0.61, 0.78, 0.50],
    #"Method 2": [0.44, 0.48, 0.45, 0.45],
    "Method 3": [0.11, 0.37, 0.41, 0.60]
}

# プロットの作成
plt.figure(figsize=(8, 6))

# 各メソッドをプロット
for method, scores in f_beta_scores.items():
    if method == "Method 2":
        plt.plot(n_values, scores, marker='o', label=method, color='green')  # Method 2 を緑に
    elif method == "Method 3":
        plt.plot(n_values, scores, marker='o', label=method, color='orange')  # Method 3 をオレンジに
    else:
        plt.plot(n_values, scores, marker='o', label=method)

# 軸ラベルとタイトルの設定
plt.title('f0.5 Score vs Number of Augmentations (2^n)', fontsize=16)
plt.xlabel('n (Number of Augmentations = $2^n$)', fontsize=14)
plt.ylabel('f0.5 Score', fontsize=14)

# X軸の目盛りをカスタマイズ（n の値）
plt.xticks(n_values, [f'$2^{n}$' for n in n_values])

# グリッドの表示
plt.grid(True, linestyle='--', alpha=0.6)

# 凡例の追加
plt.legend(fontsize=12)

# プロットの表示
plt.show()
